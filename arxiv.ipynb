# %%
def arxiv(arxiv_id, dirname='../', seq=',', output=True):
    import os
    import urllib.request as request
    from bs4 import BeautifulSoup
    import re
    import json
    
    arxiv_id = arxiv_id.strip()
    
    # URL
    url_index = 'https://arxiv.org/'
    url_abs = url_index +'abs/' + arxiv_id
    url_pdf = url_index + 'pdf/' + arxiv_id + '.pdf'

    # Set BS4
    rqt = request.urlopen(url_abs)
    print(url_abs)
    soup = BeautifulSoup(rqt, "lxml")

    # Set File name
    title = soup.find('head')
    title = title.find('title')
    title = title.get_text()
    pattern = re.compile('\n')
    title = re.sub(pattern, ' ', title)
    pattern = re.compile('\s+')
    title = re.sub(pattern, ' ', title)
    title_new = title + '.pdf'
    
    pattern = re.compile('^\[[a-z-]+/[0-9]+\]')
    title = re.sub(pattern, '', title, count=1)
    
    pattern = re.compile('^\[([0-9]{4}\.[0-9]+)\]')
    title = re.sub(pattern, '', title, count=1)
    
    # Set authers
    authers = soup.find('div', class_='authors')
    authers = authers.find_all('a')
    f = lambda x:x.get_text()
    authers = list(map(f, authers))
    
    # Set citation date
    citation_date = soup.find('meta', attrs={'name':'citation_date'})
    citation_date = citation_date.get('content')
    ####### Data Type from String Type #######            
    def str2time(time):
        import datetime as dt
        try:
            time = dt.datetime.strptime(time, '%Y/%m/%d')
        except TypeError:
            time = dt.datetime(1900, 1, 1, 0, 0)
        return time
    citation_date = str2time(citation_date)
    citation_year = str(citation_date.year)

    dirname = os.path.join(dirname, citation_year)
    if not os.path.exists(dirname):
        os.makedirs(dirname)

    pattern = '¥|/|:|\*|<|>|\|'
    title_new = re.sub(pattern, '_', title_new)
    filename = os.path.join(dirname, title_new)
    
    if not os.path.exists(filename):
        request.urlretrieve(url_pdf, '{0}'.format(filename))
        print('Save: ', filename)
    else:
        print('Allready, the file exists. ')
    contents = {
        arxiv_id:{
            'Year':citation_year, 
            'title':title, 
            'url':url_pdf, 
            'authers': authers
        }
    }
    
    for key in contents.keys():
        print(key, contents[key])
    print('')

    if output == True:
        with open('paper_list.txt', 'a') as f:
            text_line = arxiv_id + seq + title + seq + str(authers) + '\n'
            f.write(text_line)
    else:
        pass
        
    text_line = '|'+citation_year+'|'+arxiv_id + '|' + '['+title+']'+'('+url_pdf+')' + '|' + ','.join(authers)+'|' + '\n'
    print(text_line)
    return contents

# %%
arxivstr = """
    1709.01066
    1310.4546
    1301.3781
    1512.01237
    1702.02138
    1703.0687
    1312.5258
    1611.07074
    1512.01237
    1512.01237
    1601.07558
    1001.0785
    1701.04579
    0911.3635
    1312.5258
    1612.01928
    1612.03809
    1612.07837
    1702.08431
    1703.08002
    1706.05394
    1409.0473
    1504.00702
    hep-th/9810056
    1511.06410
    1409.4842
    1512.03385
"""


import re
pattern = re.compile('\s+')
arxivlist = re.split(pattern, arxivstr)
arxivlist = list(filter(lambda x:x!='', arxivlist))
list(map(arxiv, arxivlist))

# %%
L = [
    '1709.01066',
    '1310.4546',
    '1301.3781',
    '1512.01237',
    '1702.02138',
    '1703.0687',
    '1312.5258',
    '1611.07074',
    '1512.01237',
    '1512.01237',
    '1601.07558',
    '1001.0785',
    '1701.04579',
    '0911.3635',
    '1312.5258',
    '1612.01928',
    '1612.03809',
    '1612.07837',
    '1702.08431',
    '1703.08002',
    '1706.05394',
    '1409.0473',
    '1504.00702',
    'hep-th/9810056',
    '1511.06410', 
    '1409.4842', 
    '1512.03385', 
]

# %%
for i in L:
    arxiv(i, output=False)
# Out:
# https://arxiv.org/abs/1709.01066
# Allready, the file exists.
# 1709.01066 {'Year': '2017', 'title': ' Quantum Decimation in Hilbert Space: Coarse-Graining without Structure', 'url': 'https://arxiv.org/pdf/1709.01066.pdf', 'authers': ['Ashmeet Singh', 'Sean M. Carroll']}
#
# |2017|1709.01066|[ Quantum Decimation in Hilbert Space: Coarse-Graining without Structure](https://arxiv.org/pdf/1709.01066.pdf)|Ashmeet Singh,Sean M. Carroll|
#
# https://arxiv.org/abs/1310.4546
# Allready, the file exists.
# 1310.4546 {'Year': '2013', 'title': ' Distributed Representations of Words and Phrases and their Compositionality', 'url': 'https://arxiv.org/pdf/1310.4546.pdf', 'authers': ['Tomas Mikolov', 'Ilya Sutskever', 'Kai Chen', 'Greg Corrado', 'Jeffrey Dean']}
#
# |2013|1310.4546|[ Distributed Representations of Words and Phrases and their Compositionality](https://arxiv.org/pdf/1310.4546.pdf)|Tomas Mikolov,Ilya Sutskever,Kai Chen,Greg Corrado,Jeffrey Dean|
#
# https://arxiv.org/abs/1301.3781
# Allready, the file exists.
# 1301.3781 {'Year': '2013', 'title': ' Efficient Estimation of Word Representations in Vector Space', 'url': 'https://arxiv.org/pdf/1301.3781.pdf', 'authers': ['Tomas Mikolov', 'Kai Chen', 'Greg Corrado', 'Jeffrey Dean']}
#
# |2013|1301.3781|[ Efficient Estimation of Word Representations in Vector Space](https://arxiv.org/pdf/1301.3781.pdf)|Tomas Mikolov,Kai Chen,Greg Corrado,Jeffrey Dean|
#
# https://arxiv.org/abs/1512.01237
# Allready, the file exists.
# 1512.01237 {'Year': '2015', 'title': ' Quantum mechanics of 4-derivative theories', 'url': 'https://arxiv.org/pdf/1512.01237.pdf', 'authers': ['Alberto Salvio', 'Alessandro Strumia']}
#
# |2015|1512.01237|[ Quantum mechanics of 4-derivative theories](https://arxiv.org/pdf/1512.01237.pdf)|Alberto Salvio,Alessandro Strumia|
#
# https://arxiv.org/abs/1702.02138
# Allready, the file exists.
# 1702.02138 {'Year': '2017', 'title': ' An Implementation of Faster RCNN with Study for Region Sampling', 'url': 'https://arxiv.org/pdf/1702.02138.pdf', 'authers': ['Xinlei Chen', 'Abhinav Gupta']}
#
# |2017|1702.02138|[ An Implementation of Faster RCNN with Study for Region Sampling](https://arxiv.org/pdf/1702.02138.pdf)|Xinlei Chen,Abhinav Gupta|
#
# https://arxiv.org/abs/1703.0687
# Allready, the file exists.
# 1703.0687 {'Year': '2017', 'title': ' Even faster sorting of (not only) integers', 'url': 'https://arxiv.org/pdf/1703.0687.pdf', 'authers': ['Marek Kokot', 'Sebastian Deorowicz', 'Maciej Dlugosz']}
#
# |2017|1703.0687|[ Even faster sorting of (not only) integers](https://arxiv.org/pdf/1703.0687.pdf)|Marek Kokot,Sebastian Deorowicz,Maciej Dlugosz|
#
# https://arxiv.org/abs/1312.5258
# Allready, the file exists.
# 1312.5258 {'Year': '2013', 'title': ' On the Challenges of Physical Implementations of RBMs', 'url': 'https://arxiv.org/pdf/1312.5258.pdf', 'authers': ['Vincent Dumoulin', 'Ian J. Goodfellow', 'Aaron Courville', 'Yoshua Bengio']}
#
# |2013|1312.5258|[ On the Challenges of Physical Implementations of RBMs](https://arxiv.org/pdf/1312.5258.pdf)|Vincent Dumoulin,Ian J. Goodfellow,Aaron Courville,Yoshua Bengio|
#
# https://arxiv.org/abs/1611.07074
# Allready, the file exists.
# 1611.07074 {'Year': '2016', 'title': ' Path-integral formula for local thermal equilibrium', 'url': 'https://arxiv.org/pdf/1611.07074.pdf', 'authers': ['Masaru Hongo']}
#
# |2016|1611.07074|[ Path-integral formula for local thermal equilibrium](https://arxiv.org/pdf/1611.07074.pdf)|Masaru Hongo|
#
# https://arxiv.org/abs/1512.01237
# Allready, the file exists.
# 1512.01237 {'Year': '2015', 'title': ' Quantum mechanics of 4-derivative theories', 'url': 'https://arxiv.org/pdf/1512.01237.pdf', 'authers': ['Alberto Salvio', 'Alessandro Strumia']}
#
# |2015|1512.01237|[ Quantum mechanics of 4-derivative theories](https://arxiv.org/pdf/1512.01237.pdf)|Alberto Salvio,Alessandro Strumia|
#
# https://arxiv.org/abs/1512.01237
# Allready, the file exists.
# 1512.01237 {'Year': '2015', 'title': ' Quantum mechanics of 4-derivative theories', 'url': 'https://arxiv.org/pdf/1512.01237.pdf', 'authers': ['Alberto Salvio', 'Alessandro Strumia']}
#
# |2015|1512.01237|[ Quantum mechanics of 4-derivative theories](https://arxiv.org/pdf/1512.01237.pdf)|Alberto Salvio,Alessandro Strumia|
#
# https://arxiv.org/abs/1601.07558
# Allready, the file exists.
# 1601.07558 {'Year': '2016', 'title': ' What is the Entropy in Entropic Gravity?', 'url': 'https://arxiv.org/pdf/1601.07558.pdf', 'authers': ['Sean M. Carroll', 'Grant N. Remmen']}
#
# |2016|1601.07558|[ What is the Entropy in Entropic Gravity?](https://arxiv.org/pdf/1601.07558.pdf)|Sean M. Carroll,Grant N. Remmen|
#
# https://arxiv.org/abs/1001.0785
# Allready, the file exists.
# 1001.0785 {'Year': '2010', 'title': ' On the Origin of Gravity and the Laws of Newton', 'url': 'https://arxiv.org/pdf/1001.0785.pdf', 'authers': ['Erik P. Verlinde']}
#
# |2010|1001.0785|[ On the Origin of Gravity and the Laws of Newton](https://arxiv.org/pdf/1001.0785.pdf)|Erik P. Verlinde|
#
# https://arxiv.org/abs/1701.04579
# Allready, the file exists.
# 1701.04579 {'Year': '2017', 'title': ' Quantum Annealing amid Local Ruggedness and Global Frustration', 'url': 'https://arxiv.org/pdf/1701.04579.pdf', 'authers': ['James King', 'Sheir Yarkoni', 'Jack Raymond', 'Isil Ozfidan', 'Andrew D. King', 'Mayssam Mohammadi Nevisi', 'Jeremy P. Hilton', 'Catherine C. McGeoch']}
#
# |2017|1701.04579|[ Quantum Annealing amid Local Ruggedness and Global Frustration](https://arxiv.org/pdf/1701.04579.pdf)|James King,Sheir Yarkoni,Jack Raymond,Isil Ozfidan,Andrew D. King,Mayssam Mohammadi Nevisi,Jeremy P. Hilton,Catherine C. McGeoch|
#
# https://arxiv.org/abs/0911.3635
# Allready, the file exists.
# 0911.3635 {'Year': '2009', 'title': ' Quantum Metropolis Sampling', 'url': 'https://arxiv.org/pdf/0911.3635.pdf', 'authers': ['K. Temme', 'T.J. Osborne', 'K.G. Vollbrecht', 'D. Poulin', 'F. Verstraete']}
#
# |2009|0911.3635|[ Quantum Metropolis Sampling](https://arxiv.org/pdf/0911.3635.pdf)|K. Temme,T.J. Osborne,K.G. Vollbrecht,D. Poulin,F. Verstraete|
#
# https://arxiv.org/abs/1312.5258
# Allready, the file exists.
# 1312.5258 {'Year': '2013', 'title': ' On the Challenges of Physical Implementations of RBMs', 'url': 'https://arxiv.org/pdf/1312.5258.pdf', 'authers': ['Vincent Dumoulin', 'Ian J. Goodfellow', 'Aaron Courville', 'Yoshua Bengio']}
#
# |2013|1312.5258|[ On the Challenges of Physical Implementations of RBMs](https://arxiv.org/pdf/1312.5258.pdf)|Vincent Dumoulin,Ian J. Goodfellow,Aaron Courville,Yoshua Bengio|
#
# https://arxiv.org/abs/1612.01928
# Allready, the file exists.
# 1612.01928 {'Year': '2016', 'title': ' Invariant Representations for Noisy Speech Recognition', 'url': 'https://arxiv.org/pdf/1612.01928.pdf', 'authers': ['Dmitriy Serdyuk', 'Kartik Audhkhasi', 'Philémon Brakel', 'Bhuvana Ramabhadran', 'Samuel Thomas', 'Yoshua Bengio']}
#
# |2016|1612.01928|[ Invariant Representations for Noisy Speech Recognition](https://arxiv.org/pdf/1612.01928.pdf)|Dmitriy Serdyuk,Kartik Audhkhasi,Philémon Brakel,Bhuvana Ramabhadran,Samuel Thomas,Yoshua Bengio|
#
# https://arxiv.org/abs/1612.03809
# Allready, the file exists.
# 1612.03809 {'Year': '2016', 'title': ' Generalizable Features From Unsupervised Learning', 'url': 'https://arxiv.org/pdf/1612.03809.pdf', 'authers': ['Mehdi Mirza', 'Aaron Courville', 'Yoshua Bengio']}
#
# |2016|1612.03809|[ Generalizable Features From Unsupervised Learning](https://arxiv.org/pdf/1612.03809.pdf)|Mehdi Mirza,Aaron Courville,Yoshua Bengio|
#
# https://arxiv.org/abs/1612.07837
# Allready, the file exists.
# 1612.07837 {'Year': '2016', 'title': ' SampleRNN: An Unconditional End-to-End Neural Audio Generation Model', 'url': 'https://arxiv.org/pdf/1612.07837.pdf', 'authers': ['Soroush Mehri', 'Kundan Kumar', 'Ishaan Gulrajani', 'Rithesh Kumar', 'Shubham Jain', 'Jose Sotelo', 'Aaron Courville', 'Yoshua Bengio']}
#
# |2016|1612.07837|[ SampleRNN: An Unconditional End-to-End Neural Audio Generation Model](https://arxiv.org/pdf/1612.07837.pdf)|Soroush Mehri,Kundan Kumar,Ishaan Gulrajani,Rithesh Kumar,Shubham Jain,Jose Sotelo,Aaron Courville,Yoshua Bengio|
#
# https://arxiv.org/abs/1702.08431
# Allready, the file exists.
# 1702.08431 {'Year': '2017', 'title': ' Boundary-Seeking Generative Adversarial Networks', 'url': 'https://arxiv.org/pdf/1702.08431.pdf', 'authers': ['R Devon Hjelm', 'Athul Paul Jacob', 'Tong Che', 'Adam Trischler', 'Kyunghyun Cho', 'Yoshua Bengio']}
#
# |2017|1702.08431|[ Boundary-Seeking Generative Adversarial Networks](https://arxiv.org/pdf/1702.08431.pdf)|R Devon Hjelm,Athul Paul Jacob,Tong Che,Adam Trischler,Kyunghyun Cho,Yoshua Bengio|
# https://arxiv.org/abs/1703.08002
# Allready, the file exists.
# 1703.08002 {'Year': '2017', 'title': ' A network of deep neural networks for distant speech recognition', 'url': 'https://arxiv.org/pdf/1703.08002.pdf', 'authers': ['Mirco Ravanelli', 'Philemon Brakel', 'Maurizio Omologo', 'Yoshua Bengio']}
#
# |2017|1703.08002|[ A network of deep neural networks for distant speech recognition](https://arxiv.org/pdf/1703.08002.pdf)|Mirco Ravanelli,Philemon Brakel,Maurizio Omologo,Yoshua Bengio|
#
# https://arxiv.org/abs/1706.05394
# Allready, the file exists.
# 1706.05394 {'Year': '2017', 'title': ' A Closer Look at Memorization in Deep Networks', 'url': 'https://arxiv.org/pdf/1706.05394.pdf', 'authers': ['Devansh Arpit', 'Stanisław Jastrzębski', 'Nicolas Ballas', 'David Krueger', 'Emmanuel Bengio', 'Maxinder S. Kanwal', 'Tegan Maharaj', 'Asja Fischer', 'Aaron Courville', 'Yoshua Bengio', 'Simon Lacoste-Julien']}
#
# |2017|1706.05394|[ A Closer Look at Memorization in Deep Networks](https://arxiv.org/pdf/1706.05394.pdf)|Devansh Arpit,Stanisław Jastrzębski,Nicolas Ballas,David Krueger,Emmanuel Bengio,Maxinder S. Kanwal,Tegan Maharaj,Asja Fischer,Aaron Courville,Yoshua Bengio,Simon Lacoste-Julien|
#
# https://arxiv.org/abs/1409.0473
# Allready, the file exists.
# 1409.0473 {'Year': '2014', 'title': ' Neural Machine Translation by Jointly Learning to Align and Translate', 'url': 'https://arxiv.org/pdf/1409.0473.pdf', 'authers': ['Dzmitry Bahdanau', 'Kyunghyun Cho', 'Yoshua Bengio']}
#
# |2014|1409.0473|[ Neural Machine Translation by Jointly Learning to Align and Translate](https://arxiv.org/pdf/1409.0473.pdf)|Dzmitry Bahdanau,Kyunghyun Cho,Yoshua Bengio|
#
# https://arxiv.org/abs/1504.00702
# Allready, the file exists.
# 1504.00702 {'Year': '2015', 'title': ' End-to-End Training of Deep Visuomotor Policies', 'url': 'https://arxiv.org/pdf/1504.00702.pdf', 'authers': ['Sergey Levine', 'Chelsea Finn', 'Trevor Darrell', 'Pieter Abbeel']}
#
# |2015|1504.00702|[ End-to-End Training of Deep Visuomotor Policies](https://arxiv.org/pdf/1504.00702.pdf)|Sergey Levine,Chelsea Finn,Trevor Darrell,Pieter Abbeel|
#
# https://arxiv.org/abs/hep-th/9810056
# Allready, the file exists.
# hep-th/9810056 {'Year': '1998', 'title': ' Wilson Renormalization Group and Continuum Effective Field Theories', 'url': 'https://arxiv.org/pdf/hep-th/9810056.pdf', 'authers': ['Chanju Kim']}
#
# |1998|hep-th/9810056|[ Wilson Renormalization Group and Continuum Effective Field Theories](https://arxiv.org/pdf/hep-th/9810056.pdf)|Chanju Kim|
#
# https://arxiv.org/abs/1511.06410
# Allready, the file exists.
# 1511.06410 {'Year': '2015', 'title': ' Better Computer Go Player with Neural Network and Long-term Prediction', 'url': 'https://arxiv.org/pdf/1511.06410.pdf', 'authers': ['Yuandong Tian', 'Yan Zhu']}
#
# |2015|1511.06410|[ Better Computer Go Player with Neural Network and Long-term Prediction](https://arxiv.org/pdf/1511.06410.pdf)|Yuandong Tian,Yan Zhu|
#
# https://arxiv.org/abs/1409.4842
# Save:  ../2014/[1409.4842] Going Deeper with Convolutions.pdf
# 1409.4842 {'Year': '2014', 'title': ' Going Deeper with Convolutions', 'url': 'https://arxiv.org/pdf/1409.4842.pdf', 'authers': ['Christian Szegedy', 'Wei Liu', 'Yangqing Jia', 'Pierre Sermanet', 'Scott Reed', 'Dragomir Anguelov', 'Dumitru Erhan', 'Vincent Vanhoucke', 'Andrew Rabinovich']}
#
# |2014|1409.4842|[ Going Deeper with Convolutions](https://arxiv.org/pdf/1409.4842.pdf)|Christian Szegedy,Wei Liu,Yangqing Jia,Pierre Sermanet,Scott Reed,Dragomir Anguelov,Dumitru Erhan,Vincent Vanhoucke,Andrew Rabinovich|
#
# https://arxiv.org/abs/1512.03385
# Save:  ../2015/[1512.03385] Deep Residual Learning for Image Recognition.pdf
# 1512.03385 {'Year': '2015', 'title': ' Deep Residual Learning for Image Recognition', 'url': 'https://arxiv.org/pdf/1512.03385.pdf', 'authers': ['Kaiming He', 'Xiangyu Zhang', 'Shaoqing Ren', 'Jian Sun']}
#
# |2015|1512.03385|[ Deep Residual Learning for Image Recognition](https://arxiv.org/pdf/1512.03385.pdf)|Kaiming He,Xiangyu Zhang,Shaoqing Ren,Jian Sun|

# %%
while True:
    arxiv(input('arXiv'))
# Out:
# arXiv1504.00702
# https://arxiv.org/abs/1504.00702
# Save:  ../2015/[1504.00702] End-to-End Training of Deep Visuomotor Policies.pdf
# 1504.00702 {'title': ' End-to-End Training of Deep Visuomotor Policies', 'authers': ['Sergey Levine', 'Chelsea Finn', 'Trevor Darrell', 'Pieter Abbeel']}
# -------------------------------------------------------------
# KeyboardInterrupt           Traceback (most recent call last)
# ~/.pyenv/versions/3.6.3/envs/tf/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# ~/.pyenv/versions/3.6.3/envs/tf/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/.pyenv/versions/3.6.3/envs/tf/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/.pyenv/versions/3.6.3/envs/tf/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt           Traceback (most recent call last)
# <ipython-input-35-a85200d52cfe> in <module>()
#       1 while True:
# ----> 2     arxiv(input('arXiv'))
#
# ~/.pyenv/versions/3.6.3/envs/tf/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# ~/.pyenv/versions/3.6.3/envs/tf/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
arxiv('hep-th/9810056')
arxiv('1709.01066')
arxiv('1310.4546')
arxiv('1301.3781')
arxiv('1512.01237')
arxiv('1702.02138')
arxiv('1703.06870')
arxiv('1312.5258')
arxiv('1611.07074')
arxiv('1512.01237')
arxiv('1512.01237')
arxiv('1601.07558')
arxiv('1001.0785')
arxiv('1701.04579')
arxiv('0911.3635')
arxiv('1312.5258')
arxiv('1612.01928')
arxiv('1612.03809')
arxiv('1612.07837')
arxiv('1702.08431')
arxiv('1703.08002')
arxiv('1706.05394')
arxiv('1409.0473')
# Out:
# https://arxiv.org/abs/hep-th/9810056
# Allready, the file exists.
# hep-th/9810056 {'title': '[hep-th/9810056] Wilson Renormalization Group and Continuum Effective Field Theories', 'authers': ['Chanju Kim']}
#
# https://arxiv.org/abs/1709.01066
# Allready, the file exists.
# 1709.01066 {'title': ' Quantum Decimation in Hilbert Space: Coarse-Graining without Structure', 'authers': ['Ashmeet Singh', 'Sean M. Carroll']}
#
# https://arxiv.org/abs/1310.4546
# Allready, the file exists.
# 1310.4546 {'title': ' Distributed Representations of Words and Phrases and their Compositionality', 'authers': ['Tomas Mikolov', 'Ilya Sutskever', 'Kai Chen', 'Greg Corrado', 'Jeffrey Dean']}
#
# https://arxiv.org/abs/1301.3781
# Allready, the file exists.
# 1301.3781 {'title': ' Efficient Estimation of Word Representations in Vector Space', 'authers': ['Tomas Mikolov', 'Kai Chen', 'Greg Corrado', 'Jeffrey Dean']}
#
# https://arxiv.org/abs/1512.01237
# Allready, the file exists.
# 1512.01237 {'title': ' Quantum mechanics of 4-derivative theories', 'authers': ['Alberto Salvio', 'Alessandro Strumia']}
#
# https://arxiv.org/abs/1702.02138
# Allready, the file exists.
# 1702.02138 {'title': ' An Implementation of Faster RCNN with Study for Region Sampling', 'authers': ['Xinlei Chen', 'Abhinav Gupta']}
#
# https://arxiv.org/abs/1703.06870
# Allready, the file exists.
# 1703.06870 {'title': ' Mask R-CNN', 'authers': ['Kaiming He', 'Georgia Gkioxari', 'Piotr Dollár', 'Ross Girshick']}
#
# https://arxiv.org/abs/1312.5258
# Allready, the file exists.
# 1312.5258 {'title': ' On the Challenges of Physical Implementations of RBMs', 'authers': ['Vincent Dumoulin', 'Ian J. Goodfellow', 'Aaron Courville', 'Yoshua Bengio']}
#
# https://arxiv.org/abs/1611.07074
# Allready, the file exists.
# 1611.07074 {'title': ' Path-integral formula for local thermal equilibrium', 'authers': ['Masaru Hongo']}
#
# https://arxiv.org/abs/1512.01237
# Allready, the file exists.
# 1512.01237 {'title': ' Quantum mechanics of 4-derivative theories', 'authers': ['Alberto Salvio', 'Alessandro Strumia']}
#
# https://arxiv.org/abs/1512.01237
# Allready, the file exists.
# 1512.01237 {'title': ' Quantum mechanics of 4-derivative theories', 'authers': ['Alberto Salvio', 'Alessandro Strumia']}
#
# https://arxiv.org/abs/1601.07558
# Allready, the file exists.
# 1601.07558 {'title': ' What is the Entropy in Entropic Gravity?', 'authers': ['Sean M. Carroll', 'Grant N. Remmen']}
#
# https://arxiv.org/abs/1001.0785
# Allready, the file exists.
# 1001.0785 {'title': ' On the Origin of Gravity and the Laws of Newton', 'authers': ['Erik P. Verlinde']}
#
# https://arxiv.org/abs/1701.04579
# Allready, the file exists.
# 1701.04579 {'title': ' Quantum Annealing amid Local Ruggedness and Global Frustration', 'authers': ['James King', 'Sheir Yarkoni', 'Jack Raymond', 'Isil Ozfidan', 'Andrew D. King', 'Mayssam Mohammadi Nevisi', 'Jeremy P. Hilton', 'Catherine C. McGeoch']}
#
# https://arxiv.org/abs/0911.3635
# Allready, the file exists.
# 0911.3635 {'title': ' Quantum Metropolis Sampling', 'authers': ['K. Temme', 'T.J. Osborne', 'K.G. Vollbrecht', 'D. Poulin', 'F. Verstraete']}
#
# https://arxiv.org/abs/1312.5258
# Allready, the file exists.
# 1312.5258 {'title': ' On the Challenges of Physical Implementations of RBMs', 'authers': ['Vincent Dumoulin', 'Ian J. Goodfellow', 'Aaron Courville', 'Yoshua Bengio']}
#
# https://arxiv.org/abs/1612.01928
# Allready, the file exists.
# 1612.01928 {'title': ' Invariant Representations for Noisy Speech Recognition', 'authers': ['Dmitriy Serdyuk', 'Kartik Audhkhasi', 'Philémon Brakel', 'Bhuvana Ramabhadran', 'Samuel Thomas', 'Yoshua Bengio']}
#
# https://arxiv.org/abs/1612.03809
# Allready, the file exists.
# 1612.03809 {'title': ' Generalizable Features From Unsupervised Learning', 'authers': ['Mehdi Mirza', 'Aaron Courville', 'Yoshua Bengio']}
#
# https://arxiv.org/abs/1612.07837
# Allready, the file exists.
# 1612.07837 {'title': ' SampleRNN: An Unconditional End-to-End Neural Audio Generation Model', 'authers': ['Soroush Mehri', 'Kundan Kumar', 'Ishaan Gulrajani', 'Rithesh Kumar', 'Shubham Jain', 'Jose Sotelo', 'Aaron Courville', 'Yoshua Bengio']}
#
# https://arxiv.org/abs/1702.08431
# Allready, the file exists.
# 1702.08431 {'title': ' Boundary-Seeking Generative Adversarial Networks', 'authers': ['R Devon Hjelm', 'Athul Paul Jacob', 'Tong Che', 'Adam Trischler', 'Kyunghyun Cho', 'Yoshua Bengio']}
#
# https://arxiv.org/abs/1703.08002
# Allready, the file exists.
# 1703.08002 {'title': ' A network of deep neural networks for distant speech recognition', 'authers': ['Mirco Ravanelli', 'Philemon Brakel', 'Maurizio Omologo', 'Yoshua Bengio']}
#
# https://arxiv.org/abs/1706.05394
# Allready, the file exists.
# 1706.05394 {'title': ' A Closer Look at Memorization in Deep Networks', 'authers': ['Devansh Arpit', 'Stanisław Jastrzębski', 'Nicolas Ballas', 'David Krueger', 'Emmanuel Bengio', 'Maxinder S. Kanwal', 'Tegan Maharaj', 'Asja Fischer', 'Aaron Courville', 'Yoshua Bengio', 'Simon Lacoste-Julien']}
#
# https://arxiv.org/abs/1409.0473
# Allready, the file exists.
# 1409.0473 {'title': ' Neural Machine Translation by Jointly Learning to Align and Translate', 'authers': ['Dzmitry Bahdanau', 'Kyunghyun Cho', 'Yoshua Bengio']}
# {'1409.0473': {'title': ' Neural Machine Translation by Jointly Learning to Align and Translate',
#   'authers': ['Dzmitry Bahdanau', 'Kyunghyun Cho', 'Yoshua Bengio']}}

# %%
import pandas as pd
list(map(lambda x:x.split(',')[0], pd.read_table('./paper_list.txt', header=-1)[0]))
# Out:
# ['hep-th/9810056',
#  '1709.01066',
#  '1310.4546',
#  '1301.3781',
#  '1512.01237',
#  '1702.02138',
#  '1703.06870',
#  '1312.5258',
#  '1611.07074',
#  '1512.01237',
#  '1512.01237',
#  '1601.07558',
#  '1001.0785',
#  '1701.04579',
#  '0911.3635',
#  '1312.5258',
#  '1612.01928',
#  '1612.03809',
#  '1612.07837',
#  '1702.08431',
#  '1703.08002',
#  '1706.05394',
#  '1409.0473',
#  '1504.00702']
